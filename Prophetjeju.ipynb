# %% [markdown]
# # prophet 써봄

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install prophet
from prophet import Prophet


import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Requirement already satisfied: prophet in /usr/local/lib/python3.10/dist-packages (1.1.5)
# Requirement already satisfied: cmdstanpy>=1.0.4 in /usr/local/lib/python3.10/dist-packages (from prophet) (1.2.0)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.10/dist-packages (from prophet) (1.23.5)
# Requirement already satisfied: matplotlib>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from prophet) (3.7.1)
# Requirement already satisfied: pandas>=1.0.4 in /usr/local/lib/python3.10/dist-packages (from prophet) (1.5.3)
# Requirement already satisfied: holidays>=0.25 in /usr/local/lib/python3.10/dist-packages (from prophet) (0.35)
# Requirement already satisfied: tqdm>=4.36.1 in /usr/local/lib/python3.10/dist-packages (from prophet) (4.66.1)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from prophet) (6.1.0)
# Requirement already satisfied: stanio~=0.3.0 in /usr/local/lib/python3.10/dist-packages (from cmdstanpy>=1.0.4->prophet) (0.3.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from holidays>=0.25->prophet) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (4.44.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (3.1.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.4->prophet) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil->holidays>=0.25->prophet) (1.16.0)

# %%
# 파일경로
train_file_path = '/content/drive/MyDrive/open-2/train.csv'
test_file_path = '/content/drive/MyDrive/open-2/test.csv'
trade_file_path = '/content/drive/MyDrive/open-2/international_trade.csv'

# csv 파일 불러옴
train_data = pd.read_csv(train_file_path)
test_data = pd.read_csv(test_file_path)
trade_data = pd.read_csv(trade_file_path)

sample_file_path = '/content/drive/MyDrive/open-2/sample_submission.csv'
submission_df = pd.read_csv(sample_file_path)

# %% [markdown]
# # 전처리
# - prophet 모델에 맞춰서 데이터프레임 맞춤
# - ID, ds, y컬럼만 선택해서 만듬
# - ID 컬럼에서 정규표현식으로 _ 뒤 8자리 숫자 제거

# %%
prophet_data = train_data.rename(columns={'timestamp': 'ds', 'price(원/kg)': 'y'})
prophet_data = prophet_data[['ID', 'ds', 'y']]
prophet_data['ID'] = prophet_data['ID'].str.replace(r'_\d{8}$', '', regex=True)

# %% [markdown]
# # 모델
# - 주어진 데이터프레임에서 고유한 ID 목록 추출
# - 2023-3-4 부터 시작해서 28일 동안 미래 날짜 데이터프레임 생성
# - 모델 설정값은 기본값임 바꿔야됨

# %%
RANDOM_SEED = 990313
np.random.seed(RANDOM_SEED)
def ph_train(df):
    pred_list = []
    for code in df['ID'].unique():
        d = df[df['ID'] == code].reset_index().drop(['ID'], axis=1).sort_values('ds')
        model = Prophet(
          growth='linear',
          changepoints=None,
          n_changepoints=25,
          changepoint_range=0.8,
          yearly_seasonality='auto',
          weekly_seasonality='auto',
          daily_seasonality='auto',
          holidays=None,
          seasonality_mode='additive',
          seasonality_prior_scale=10.0,
          holidays_prior_scale=10.0,
          changepoint_prior_scale=0.05,
          mcmc_samples=0,
          interval_width=0.8,
          uncertainty_samples=1000
        )
        model.fit(d)
        future = pd.DataFrame()
        future['ds'] = pd.date_range(start='2023-03-04', periods=28, freq='D')
        forecast = model.predict(future)
        pred_y = forecast['yhat'].values
        pred_code = [str(code)] * len(pred_y)
        for y_val, id_val in zip(pred_y, pred_code):
            pred_list.append({'ID': id_val, 'y': y_val})
    pred = pd.DataFrame(pred_list)
    return pred
pred = ph_train(prophet_data)
submission_df['answer'] = pred['y']
submission_df.to_csv('prophet.csv',index=False)
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph0m0yk28/7em_rpkl.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph0m0yk28/oaw1e8u5.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=70321', 'data', 'file=/tmp/tmph0m0yk28/7em_rpkl.json', 'init=/tmp/tmph0m0yk28/oaw1e8u5.json', 'output', 'file=/tmp/tmph0m0yk28/prophet_modelpin_t6jc/prophet_model-20231108010849.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:08:49 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:08:50 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph0m0yk28/oq155b61.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph0m0yk28/m_eouyl4.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=84467', 'data', 'file=/tmp/tmph0m0yk28/oq155b61.json', 'init=/tmp/tmph0m0yk28/m_eouyl4.json', 'output', 'file=/tmp/tmph0m0yk28/prophet_modelgn4jtaf2/prophet_model-20231108010850.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:08:50 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:08:50 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph0m0yk28/m4ga4hdi.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph0m0yk28/_rv9is8j.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=49036', 'data', 'file=/tmp/tmph0m0yk28/m4ga4hdi.json', 'init=/tmp/tmph0m0yk28/_rv9is8j.json', 'output', 'file=/tmp/tmph0m0yk28/prophet_model_xqm2ojy/prophet_model-20231108010851.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:08:51 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:08:51 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph0m0yk28/ysfvznjh.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph0m0yk28/gmbwepiv.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=30437', 'data', 'file=/tmp/tmph0m0yk28/ysfvznjh.json', 'init=/tmp/tmph0m0yk28/gmbwepiv.json', 'output', 'file=/tmp/tmph0m0yk28/prophet_model73w3s6gr/prophet_model-20231108010851.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:08:51 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:08:51 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph0m0yk28/kl55sls2.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph0m0yk28/mvcszti_.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=59821', 'data', 'file=/tmp/tmph0m0yk28/kl55sls2.json', 'init=/tmp/tmph0m0yk28/mvcszti_.json', 'output', 'file=/tmp/tmph0m0yk28/prophet_modelk54dp57c/prophet_model-20231108010852.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:08:52 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:08:52 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph0m0yk28/xyxtory4.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph0m0yk28/zd00j8xc.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=85709', 'data', 'file=/tmp/tmph0m0yk28/xyxtory4.json', 'init=/tmp/tmph0m0yk28/zd00j8xc.json', 'output', 'file=/tmp/tmph0m0yk28/prophet_modelg1w_qw7f/prophet_model-20231108010852.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:08:52 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:08:53 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph0m0yk28/nuxw2gkq.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph0m0yk28/7r2rg8sm.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=19127', 'data', 'file=/tmp/tmph0m0yk28/nuxw2gkq.json', 'init=/tmp/tmph0m0yk28/7r2rg8sm.json', 'output', 'file=/tmp/tmph0m0yk28/prophet_modeldmuit8_2/prophet_model-20231108010853.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:08:53 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:08:53 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph0m0yk28/niwt1bjj.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph0m0yk28/wdme9hic.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=92643', 'data', 'file=/tmp/tmph0m0yk28/niwt1bjj.json', 'init=/tmp/tmph0m0yk28/wdme9hic.json', 'output', 'file=/tmp/tmph0m0yk28/prophet_modelj8_wjr91/prophet_model-20231108010854.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:08:54 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:08:54 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph0m0yk28/xhzr06x3.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph0m0yk28/69x6_ava.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=94458', 'data', 'file=/tmp/tmph0m0yk28/xhzr06x3.json', 'init=/tmp/tmph0m0yk28/69x6_ava.json', 'output', 'file=/tmp/tmph0m0yk28/prophet_models9vpo2tk/prophet_model-20231108010854.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:08:54 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:08:55 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph0m0yk28/pj692loy.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph0m0yk28/cqmvarbx.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=14889', 'data', 'file=/tmp/tmph0m0yk28/pj692loy.json', 'init=/tmp/tmph0m0yk28/cqmvarbx.json', 'output', 'file=/tmp/tmph0m0yk28/prophet_modelygudcdfs/prophet_model-20231108010855.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:08:55 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:08:55 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph0m0yk28/7ifuxvtd.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph0m0yk28/lgmeq2nw.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=86149', 'data', 'file=/tmp/tmph0m0yk28/7ifuxvtd.json', 'init=/tmp/tmph0m0yk28/lgmeq2nw.json', 'output', 'file=/tmp/tmph0m0yk28/prophet_modelqhih74a5/prophet_model-20231108010855.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:08:55 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:08:55 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph0m0yk28/ej4y_nsl.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph0m0yk28/p2c8sjs8.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=78768', 'data', 'file=/tmp/tmph0m0yk28/ej4y_nsl.json', 'init=/tmp/tmph0m0yk28/p2c8sjs8.json', 'output', 'file=/tmp/tmph0m0yk28/prophet_modeldvegmjao/prophet_model-20231108010856.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:08:56 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:08:56 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph0m0yk28/s_nu3kk2.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph0m0yk28/agaajw8y.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=77851', 'data', 'file=/tmp/tmph0m0yk28/s_nu3kk2.json', 'init=/tmp/tmph0m0yk28/agaajw8y.json', 'output', 'file=/tmp/tmph0m0yk28/prophet_modelyswoifil/prophet_model-20231108010856.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:08:56 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:08:56 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph0m0yk28/4durcmfe.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph0m0yk28/8jjz0goj.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=94360', 'data', 'file=/tmp/tmph0m0yk28/4durcmfe.json', 'init=/tmp/tmph0m0yk28/8jjz0goj.json', 'output', 'file=/tmp/tmph0m0yk28/prophet_modelqyu809_p/prophet_model-20231108010856.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:08:56 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:08:57 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph0m0yk28/v6l5oh9q.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph0m0yk28/dx07w6cs.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=66564', 'data', 'file=/tmp/tmph0m0yk28/v6l5oh9q.json', 'init=/tmp/tmph0m0yk28/dx07w6cs.json', 'output', 'file=/tmp/tmph0m0yk28/prophet_model6hfu2jz2/prophet_model-20231108010857.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:08:57 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:08:57 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph0m0yk28/1m1rlfg0.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph0m0yk28/1znjtegr.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=18820', 'data', 'file=/tmp/tmph0m0yk28/1m1rlfg0.json', 'init=/tmp/tmph0m0yk28/1znjtegr.json', 'output', 'file=/tmp/tmph0m0yk28/prophet_modellileg76g/prophet_model-20231108010857.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:08:57 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:08:57 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph0m0yk28/py8_p2b6.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph0m0yk28/0j_jk446.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=7821', 'data', 'file=/tmp/tmph0m0yk28/py8_p2b6.json', 'init=/tmp/tmph0m0yk28/0j_jk446.json', 'output', 'file=/tmp/tmph0m0yk28/prophet_model0vhxpry7/prophet_model-20231108010857.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:08:57 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:08:58 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph0m0yk28/yvkstdpe.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph0m0yk28/hifqgwbi.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=57844', 'data', 'file=/tmp/tmph0m0yk28/yvkstdpe.json', 'init=/tmp/tmph0m0yk28/hifqgwbi.json', 'output', 'file=/tmp/tmph0m0yk28/prophet_model59ul0ljv/prophet_model-20231108010858.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:08:58 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:08:58 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph0m0yk28/z_jsccse.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph0m0yk28/uwevjq5y.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=77193', 'data', 'file=/tmp/tmph0m0yk28/z_jsccse.json', 'init=/tmp/tmph0m0yk28/uwevjq5y.json', 'output', 'file=/tmp/tmph0m0yk28/prophet_modelgyg0zjcu/prophet_model-20231108010858.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:08:58 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:08:58 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph0m0yk28/m5o_f2nz.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph0m0yk28/wnkhjev_.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=51233', 'data', 'file=/tmp/tmph0m0yk28/m5o_f2nz.json', 'init=/tmp/tmph0m0yk28/wnkhjev_.json', 'output', 'file=/tmp/tmph0m0yk28/prophet_modelza0v_1im/prophet_model-20231108010859.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:08:59 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:08:59 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph0m0yk28/v_ujsb3a.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph0m0yk28/syrrb9id.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=79710', 'data', 'file=/tmp/tmph0m0yk28/v_ujsb3a.json', 'init=/tmp/tmph0m0yk28/syrrb9id.json', 'output', 'file=/tmp/tmph0m0yk28/prophet_modell_gsz8fs/prophet_model-20231108010859.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:08:59 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:08:59 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph0m0yk28/p5atnta4.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph0m0yk28/tdg717ue.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=36278', 'data', 'file=/tmp/tmph0m0yk28/p5atnta4.json', 'init=/tmp/tmph0m0yk28/tdg717ue.json', 'output', 'file=/tmp/tmph0m0yk28/prophet_model2kf0h1rv/prophet_model-20231108010859.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:08:59 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:09:00 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph0m0yk28/gdafdnsh.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph0m0yk28/yww9izvo.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=31950', 'data', 'file=/tmp/tmph0m0yk28/gdafdnsh.json', 'init=/tmp/tmph0m0yk28/yww9izvo.json', 'output', 'file=/tmp/tmph0m0yk28/prophet_modelvv6clax6/prophet_model-20231108010900.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:09:00 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:09:00 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph0m0yk28/vex1sq4r.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph0m0yk28/7ve1ezps.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=59690', 'data', 'file=/tmp/tmph0m0yk28/vex1sq4r.json', 'init=/tmp/tmph0m0yk28/7ve1ezps.json', 'output', 'file=/tmp/tmph0m0yk28/prophet_modelwp0l8qni/prophet_model-20231108010900.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:09:00 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:09:00 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph0m0yk28/j23ctcew.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph0m0yk28/5uv8acqq.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=96495', 'data', 'file=/tmp/tmph0m0yk28/j23ctcew.json', 'init=/tmp/tmph0m0yk28/5uv8acqq.json', 'output', 'file=/tmp/tmph0m0yk28/prophet_modelbbwi2_fs/prophet_model-20231108010901.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:09:01 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:09:01 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph0m0yk28/et3_jip2.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph0m0yk28/3mj11oll.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=21772', 'data', 'file=/tmp/tmph0m0yk28/et3_jip2.json', 'init=/tmp/tmph0m0yk28/3mj11oll.json', 'output', 'file=/tmp/tmph0m0yk28/prophet_modelbjppg0ja/prophet_model-20231108010901.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:09:01 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:09:01 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph0m0yk28/kgwwc3s0.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph0m0yk28/343xmfod.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=85730', 'data', 'file=/tmp/tmph0m0yk28/kgwwc3s0.json', 'init=/tmp/tmph0m0yk28/343xmfod.json', 'output', 'file=/tmp/tmph0m0yk28/prophet_modelqp4roytm/prophet_model-20231108010901.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:09:01 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:09:01 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph0m0yk28/ex6lwsl4.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph0m0yk28/eyl4a01j.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=24469', 'data', 'file=/tmp/tmph0m0yk28/ex6lwsl4.json', 'init=/tmp/tmph0m0yk28/eyl4a01j.json', 'output', 'file=/tmp/tmph0m0yk28/prophet_modelzokd9ouf/prophet_model-20231108010902.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:09:02 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:09:02 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph0m0yk28/0_4yq1b4.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph0m0yk28/hrzfkx9w.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=37624', 'data', 'file=/tmp/tmph0m0yk28/0_4yq1b4.json', 'init=/tmp/tmph0m0yk28/hrzfkx9w.json', 'output', 'file=/tmp/tmph0m0yk28/prophet_model69vwso0k/prophet_model-20231108010902.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:09:02 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:09:02 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph0m0yk28/vltzu_ug.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph0m0yk28/u_g9fd8b.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=8315', 'data', 'file=/tmp/tmph0m0yk28/vltzu_ug.json', 'init=/tmp/tmph0m0yk28/u_g9fd8b.json', 'output', 'file=/tmp/tmph0m0yk28/prophet_modelhmnjtd89/prophet_model-20231108010902.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:09:02 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:09:02 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph0m0yk28/q65tbx_l.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph0m0yk28/fmwdhddg.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=32332', 'data', 'file=/tmp/tmph0m0yk28/q65tbx_l.json', 'init=/tmp/tmph0m0yk28/fmwdhddg.json', 'output', 'file=/tmp/tmph0m0yk28/prophet_model4p6nal1i/prophet_model-20231108010903.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:09:03 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:09:03 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph0m0yk28/goo4c_wo.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph0m0yk28/rturp8xh.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=29704', 'data', 'file=/tmp/tmph0m0yk28/goo4c_wo.json', 'init=/tmp/tmph0m0yk28/rturp8xh.json', 'output', 'file=/tmp/tmph0m0yk28/prophet_model9zc5uq9g/prophet_model-20231108010903.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:09:03 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:09:03 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph0m0yk28/0dwphy7_.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph0m0yk28/t1o7tryz.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=42420', 'data', 'file=/tmp/tmph0m0yk28/0dwphy7_.json', 'init=/tmp/tmph0m0yk28/t1o7tryz.json', 'output', 'file=/tmp/tmph0m0yk28/prophet_modelo0t66noo/prophet_model-20231108010903.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:09:03 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:09:04 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph0m0yk28/hczyvz8f.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph0m0yk28/ahmogbhv.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=49039', 'data', 'file=/tmp/tmph0m0yk28/hczyvz8f.json', 'init=/tmp/tmph0m0yk28/ahmogbhv.json', 'output', 'file=/tmp/tmph0m0yk28/prophet_modeljqi_n249/prophet_model-20231108010904.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:09:04 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:09:04 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph0m0yk28/qtmbn47j.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph0m0yk28/4f172mp3.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=48093', 'data', 'file=/tmp/tmph0m0yk28/qtmbn47j.json', 'init=/tmp/tmph0m0yk28/4f172mp3.json', 'output', 'file=/tmp/tmph0m0yk28/prophet_modelese4m_kp/prophet_model-20231108010905.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:09:05 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:09:05 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph0m0yk28/p2sf593s.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph0m0yk28/l20zpmpj.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=230', 'data', 'file=/tmp/tmph0m0yk28/p2sf593s.json', 'init=/tmp/tmph0m0yk28/l20zpmpj.json', 'output', 'file=/tmp/tmph0m0yk28/prophet_model0shx6q2c/prophet_model-20231108010906.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:09:06 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:09:06 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph0m0yk28/c7sl7ln2.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph0m0yk28/xx8fgjw7.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=51379', 'data', 'file=/tmp/tmph0m0yk28/c7sl7ln2.json', 'init=/tmp/tmph0m0yk28/xx8fgjw7.json', 'output', 'file=/tmp/tmph0m0yk28/prophet_modelnf10_g56/prophet_model-20231108010906.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:09:06 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:09:07 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph0m0yk28/yi7tbagl.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph0m0yk28/9g0lfbpa.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=72901', 'data', 'file=/tmp/tmph0m0yk28/yi7tbagl.json', 'init=/tmp/tmph0m0yk28/9g0lfbpa.json', 'output', 'file=/tmp/tmph0m0yk28/prophet_model4udxs81m/prophet_model-20231108010907.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:09:07 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:09:07 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph0m0yk28/ppgri0bn.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph0m0yk28/mx_8x1i2.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=14037', 'data', 'file=/tmp/tmph0m0yk28/ppgri0bn.json', 'init=/tmp/tmph0m0yk28/mx_8x1i2.json', 'output', 'file=/tmp/tmph0m0yk28/prophet_modelpi5l8ov5/prophet_model-20231108010908.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:09:08 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:09:08 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
submission_df.to_csv('/content/drive/My Drive/prophet.csv', index=False)
